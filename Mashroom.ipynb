# %%
##Importing the general library
import pandas as pd

# %%
df =pd.read_csv(r'C:\Users\DELL\Downloads\mushrooms.csv')
df.tail()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %% [markdown]
# ### As the data is in catrogical, So i will change it to interger.

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
le=LabelEncoder()
cols =['class','cap-shape','cap-surface','cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
df[cols] = df[cols].apply(le.fit_transform)
df.tail()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 8119                         2                       5
# 8120                         2                       5
# ...

# %%
##Now we checking the missing data and stats of dataset.
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
x=df.drop(columns=['class'])
y=df['class']
plt.figure(figsize=(30,25), facecolor='white')
mlt = 1
for column in x:
    if mlt <= 24:
        ax = plt.subplot(6,4, mlt)
        sns.scatterplot(x[column],y)
        plt.xlabel(column, fontsize =25)
    mlt+=1
plt.tight_layout()

# %% [markdown]
# # From the above, I conclude that approx all feature has some trend with target but Veli-type has no value and trend with target.

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %% [markdown]
# ##### Checking multicollinearity between feature with the help of Heatmap

# %%
plt.figure(figsize=(30,25))
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=0.5, linecolor='black')
plt.show()

# %% [markdown]
# ## Veli type has no relation with target and also with features. So, I will  drop the veli type feature and there feature has some relation with class but Veli color and gill attchment has relation between then, I will check them separately then drop one of them too.
#
# ### Maximu Correlation - gill-size(54%)
# ### Minimum Correlation - gill-color(55%).

# %%
sns.scatterplot('veil-color','gill-attachment', data=df)
# Out:
# <AxesSubplot:xlabel='veil-color', ylabel='gill-attachment'>

# %% [markdown]
# ## The above relation show both feature has strong corelation. So, I will drop the gill attachment feature.

# %%
#df.drop(columns=['gill-attachment','veil-type'], inplace=True )
df.shape
# Out:
# (8124, 23)

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
### Checking the datatype of all features 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int32
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %%
### Now going to check to outliers of the features 

plt.figure(figsize=(20,20), facecolor='white')
pn = 1
for column in df:
    if pn <= 24:
        ax = plt.subplot(6,4, pn)
        sns.boxplot(df[column], orient='v')
        plt.xlabel(column, fontsize =25)
    pn+=1
plt.tight_layout()

# %%
### Checking the skewness of the feature 
df.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %%
## Now checking the distrubution of the data set.

plt.figure(figsize=(20,20), facecolor='white')
mlt = 1
for column in df:
    if mlt <= 24:
        ax = plt.subplot(6,4, mlt)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize =25)
    mlt+=1
plt.tight_layout()

# %% [markdown]
# ###  All feature are not normally distributed in the DataSet

# %%
###Removing the Outliers from the dataset with the help of Z-score

from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (8124, 23)

# %%
thresold =3
print(np.where(z>3))
# Out:
# (array([1816, 2128, 2128, ..., 8121, 8123, 8123], dtype=int64), array([15, 14, 15, ..., 17,  6, 17], dtype=int64))

# %%
df_new =df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (0, 23)

# %%
### Here we lost more data but it is workable because the data is discrete 

p_loss= (8124-6538)/6568*100
p_loss
# Out:
# 24.147381242387333

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 1.03577474,  0.05017017, -0.02673986, ..., -0.53714841,
#         -0.80052972,  1.51548871],
#        [ 1.03577474,  0.05017017,  1.56319371, ...,  0.01906382,
#         -1.47485647,  0.11634762],
#        [-2.02788189,  0.05017017,  1.30592999, ...,  0.01906382,
#         -1.47485647,  1.06633941],
#        ...,
#        [-0.85127533,  0.05017017, -0.02673986, ..., -2.80619461,
#         -1.89857525,  0.70247929],
#        [-0.23408877,  0.99864626, -0.02673986, ...,  1.29862534,
#          0.15412432,  0.70247929],
#        [ 1.03577474,  0.05017017, -0.02673986, ...,  0.4401869 ,
#         -1.89857525,  0.70247929]])

# %%
### Importing he basic library for building the model

x=df.drop(columns=["class"])
y=df['class']
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
scaler = StandardScaler()

# %%
### Now we scaled the dataset
x =scaler.fit_transform(x)
x
# Out:
# array([[ 1.02971224,  0.14012794, -0.19824983, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  0.14012794,  1.76587407, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  0.14012794,  1.37304929, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.8403434 ,  0.14012794, -0.19824983, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [-0.21699152,  0.95327039, -0.19824983, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224,  0.14012794, -0.19824983, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %%
### Split the dataset in train and test dataset. 
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.25, random_state=25)

# %%
Knn = KNeighborsClassifier()

# %%
Knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
score_train=Knn.score(x_train,y_train)
score_test=Knn.score(x_test,y_test)
print("KNN score for training data", score_train)
print("KNN score for training data", score_test)
pred =Knn.predict(x_test)
Class_re = classification_report(pred, y_test)
print(Class_re)
# Out:
# KNN score for training data 1.0
# KNN score for training data 0.999507631708518
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1047
#            1       1.00      1.00      1.00       984
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031

# %% [markdown]
# ### From the above score the model is performing very good.  As the model is performing very good. So we do not need to perform any Hyperparamentertuning
